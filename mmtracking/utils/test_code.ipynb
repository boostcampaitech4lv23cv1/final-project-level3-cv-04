# %%
import numpy as np

target = np.array([[0],[0],[0]])
print(target.shape)
# Out:
# (3, 1)

# %%
test_df = {"temp":[]}

test_df["temp"].append(None)
test_df["temp"].append(None)
len(test_df["temp"])

test_df
# Out:
# {'temp': [None, None]}

# %%
import pandas as pd

df = pd.DataFrame(test_df)
df.to_csv("test.csv")

# %%
fps=24

int(1000. / fps) if fps else 0
# Out:
# 41

# %%
import os
os.path.relpath("/opt/ml/final-project-level3-cv-04","/opt/ml/final-project-level3-cv-04/mmtracking/utils")
# Out:
# '../..'

# %%
## mmcv 행동분석
import mmcv
import matplotlib.pyplot as plt
import cv2

# %%
cv2_img = cv2.imread("/opt/ml/final-project-level3-cv-04/data/20230122_1709/000001.jpg")
mmcv_cv2_img = mmcv.imread(cv2_img)
mmcv_path_img = mmcv.imread("/opt/ml/final-project-level3-cv-04/data/20230122_1709/000001.jpg")

mmcv_cv2_img == mmcv_path_img
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
plt.imshow(mmcv_cv2_img)

# %%
plt.imshow(mmcv_path_img)
